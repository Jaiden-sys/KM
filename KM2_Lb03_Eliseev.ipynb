# %% [markdown]
# # Лабораторная работа 3
# # Анимация движения секущей прямой к заданной линии на плоскости
# **Елисеев Роман Павлович**, **группа 11**

# %% [markdown]
# ## Задание 3.1а

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
# %matplotlib widget

# %%
def y(x):
    return np.sin(x)**4

# %%
x_min = 1; x_max = 5; step = 0.05;
x_array = np.arange(x_min, x_max, step)
y_array = y(x_array)

# %%
matrix = np.transpose([x_array,y_array])

# %%
fig1 = plt.figure()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
y_min, y_max = np.min(y_array), np.max(y_array)

ax1 = plt.axes()
plt.axis([x_min-0.5, x_max+0.5, y_min-0.5, y_max+0.5])
# Out:
# (np.float64(0.5),
#  np.float64(5.5),
#  np.float64(-0.499999995004082),
#  np.float64(1.4996930655910048))

# %%
line1, = ax1.plot([],[],'b') 
print(type(line1))
line1.get_xdata(), line1.get_ydata()
# Out:
# <class 'matplotlib.lines.Line2D'>
# (array([], dtype=float64), array([], dtype=float64))

# %%
# ?line1.get_xdata
# Out:
# Signature: line1.get_xdata(orig=True)
# Docstring:
# Return the xdata.
#
# If *orig* is *True*, return the original data, else the
# processed data.
# File:      ~/jupyter_env/lib/python3.12/site-packages/matplotlib/lines.py
# Type:      method

# %%
 def at_frame1(point):
    """добавляет к объекту line1 точку с координатами (point[0],point[1])
    Arguments :
    point : массив из двух элементов
    Returns : None
    """
    x_coord = list(line1.get_xdata())
    y_coord = list(line1.get_ydata())
    x_coord.append(point[0])
    y_coord.append(point[1])
    line1.set_data(x_coord, y_coord)

# %%
# ?line1.set_data
# Out:
# Signature: line1.set_data(*args)
# Docstring:
# Set the x and y data.
#
# Parameters
# ----------
# *args : (2, N) array or two 1D arrays
#
# See Also
# --------
# set_xdata
# set_ydata
# File:      ~/jupyter_env/lib/python3.12/site-packages/matplotlib/lines.py
# Type:      method

# %%
help(at_frame1)
# Out:
# Help on function at_frame1 in module __main__:
#
# at_frame1(point)
#     добавляет к объекту line1 точку с координатами (point[0],point[1])
#     Arguments :
#     point : массив из двух элементов
#     Returns : None

# %%
# ?at_frame1
# Out:
# Signature: at_frame1(point)
# Docstring:
# добавляет к объекту line1 точку с координатами (point[0],point[1])
# Arguments :
# point : массив из двух элементов
# Returns : None
# File:      /tmp/ipykernel_5209/3068009472.py
# Type:      function

# %%
fig1 = plt.figure()
ax1 = plt.axes()
plt.axis([x_min-0.5, x_max+0.5, y_min-0.5, y_max+0.5])
line1, = ax1.plot([], [],'b')
FuncAnimation(fig1, at_frame1, frames=matrix, repeat=False, interval=15)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Задание 3.1б

# %%
def x_t(t):
    return np.log(t + np.sqrt(t**2 + 1))
def y_t(t):
    return t * np.sqrt(t**2 + 1)
t_min = -10; t_max = 10; step = 0.2;
t_array = np.arange(t_min, t_max, step)
x_t_array = x_t(t_array)
y_t_array = y_t(x_t_array)
matrix_t = np.transpose([x_t_array,y_t_array])

# %%
y_t_min, y_t_max = np.min(y_t_array), np.max(y_t_array)
x_t_min, x_t_max = np.min(x_t_array), np.max(x_t_array)

# %%
 def at_frame2(point):
    """добавляет к объекту line2 точку с координатами (point[0],point[1])
    Arguments :
    point : массив из двух элементов
    Returns : None
    """
    x2_coord = list(line2.get_xdata())
    y2_coord = list(line2.get_ydata())
    x2_coord.append(point[0])
    y2_coord.append(point[1])
    line2.set_data(x2_coord, y2_coord)

# %%
# ?line2.get_xdata
# Out:
# Object `line2.get_xdata` not found.

# %%
fig2 = plt.figure()
ax2 = plt.axes()
plt.axis([x_t_min-7.5, x_t_max+7.5, y_t_min-10, y_t_max+10])
line2, = ax2.plot([], [],'b')
FuncAnimation(fig2, at_frame2, frames=matrix_t, repeat=False, interval=15)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Задание 3.2.

# %%
fig2 = plt.figure()
ax2 = plt.axes()
plt.axis([x_min-0.5, x_max+0.5, y_min-0.5, y_max+0.5])
line1, = ax2.plot(x_array, y_array,'b')  # объект для графика функции
line2, = ax2.plot([], [],'go') # объект для точки
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig2 = plt.figure()
ax2 = plt.axes()
plt.axis([x_min-0.5, x_max+0.5, y_min-0.5, y_max+0.5])
def init2():
    global line2 
    line1, = ax2.plot(x_array, y_array,'b')  
    line2, = ax2.plot([], [],'go') 
    plt.legend([r'$y(x) = \sin(x)^4$','Мovable point'])
FuncAnimation(fig2, at_frame2, frames=matrix, init_func=init2, repeat=False, interval=20)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')

# %%
fig2 = plt.figure()
ax2 = plt.axes()
plt.axis([x_t_min-7.5, x_t_max+7.5, y_t_min-10, y_t_max+10])
line2, = ax2.plot([], [],'go')
def init():
    global line3
    line1, = ax2.plot(x_t_array,y_t_array,'red')
    line2, = ax2.plot([],[],'green')
FuncAnimation(fig2, at_frame2, frames=matrix_t, init_func=init, repeat=False, interval=20)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Задание 3.3.

# %%
fig3 = plt.figure()
ax3 = plt.axes()
plt.axis([x_min-1, x_max+1, y_min-1, y_max+1])
def init():
    """cоздает начальное состояние графической области перед началом анимации"""
    global point_B, secant_line
    
    curve, = ax3.plot(x_array, y_array,'b')
    
    A = np.array([x_array[0], y_array[0]]) 
    point_A, = ax3.plot(A[0],A[1],'ro')
    
    B = np.array([x_array[-1], y_array[-1]])    
    point_B, = ax3.plot(B[0],B[1],'go') 
    
    secant_p = [A + (B - A)*t for t in [-2, 2]]
    secant_p = np.array(secant_p)
    secant_line, = ax3.plot(secant_p[:,0], secant_p[:,1],'g')
    
    plt.legend([r'$y(x) = \sin(x)^4$','Unmovable point A','Мovable point B'])
def at_frame3(point):
    """do ... 
     
    Arguments :
    
    point : массив из двух элементов, задающий координаты подвижной точки 
    
    Returns : None
    """
    ...
    
FuncAnimation(fig3, at_frame3, frames=matrix[::-1], 
              init_func=init, repeat=False, interval=20)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Задание 3.4

# %%
fig33 = plt.figure()
ax33 = plt.axes()
plt.axis([x_min-1, x_max+1, y_min-1, y_max+1])
def init3():
    """
    Создает начальное состояние графической области перед началом анимации.
    
    Returns: None
    """
    global point_B3, secant_line3

    curve, = ax33.plot(x_array, y_array,'b')

    A3 = np.array([x_array[0], y_array[0]])
    point_A3, = ax33.plot(A3[0],A3[1],'ro')

    B3 = np.array([x_array[-1], y_array[-1]])
    point_B3, = ax33.plot(B3[0],B3[1],'go')

    secant_p3 = [A3 + (B3 - A3)*t for t in [-2, 2]]
    secant_p3 = np.array(secant_p3)
    secant_line3, = ax33.plot(secant_p3[:,0], secant_p3[:,1],'g')

    plt.legend([r'$x = \log\left(t + \sqrt{t^2 + 1}\right), \quad y = t \cdot \sqrt{t^2 + 1}$','Мovable point B','Secant Line'])
def at_frame33(point):
    """
    Do: обновляет положение подвижной точки B и секущей прямой на каждом кадре анимации.

    Arguments :

    point : массив из двух элементов, задающий координаты подвижной точки B.

    Returns : None
    """
    global point_B3, secant_line3
    A3 = np.array([x_array[0], y_array[0]])
    B3 = np.array([point[0],point[1]])
    point_B3.set_data([point[0]],[point[1]])
    if B3[0]==A3[0]:
        t = sympy.Symbol('t')
        x_d=np.log(t + np.sqrt(t**2 + 1))
        y_d = t * np.sqrt(t**2 + 1)
        x_difx = sympy.diff(x_d, t)
        y_difx = sympy.diff(y_d, t) 
        k=y_difx.subs(t, t_array[0])/x_difx.subs(t, t_array[0])
        y_tanstart = np.array([A3[0],A3[1]])
        y_tanend = np.array([A3[0]+1,k+A3[1]])
        y_tan=[y_tanstart+ (y_tanend-y_tanstart)*t for t in [-1, 2]]
        y_tan = np.array(y_tan)
        secant_line3.set_data(y_tan[:,0], y_tan[:,1])
        secant_line3.set_color('r')
    else:
        secant_p3 = [A3 + (B3 - A3)*l for l in [-2, 2]]
        secant_p3 = np.array(secant_p3)
        secant_line3.set_data(secant_p3[:,0], secant_p3[:,1])
FuncAnimation(fig33, at_frame33, frames=matrix[::-1], init_func=init3, repeat=False, interval=50)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
